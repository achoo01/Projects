# %%
import pandas as pd
mydata = pd.read_excel("training_dataset.xlsx")
# Out:
#                                                 text  \
# 0  agent says for contacting best buy this is nam...
# 1  agent says name. may i please have your full n...
# 2  agent says thank you very much for calling bes...
# 3  agent says this um sorry can i ask for your co...
# 4  agent says thank you for contacting best buy t...
#
#                             label
# 0                 troubleshooting
# 1           schedule installation
# 2                trade in inquiry
# 3                account security
# 4  product availability and stock

# %%
mydata
# Out:
#                                                      text  \
# 0       agent says for contacting best buy this is nam...
# 1       agent says name. may i please have your full n...
# 2       agent says thank you very much for calling bes...
# 3       agent says this um sorry can i ask for your co...
# 4       agent says thank you for contacting best buy t...
# ...                                                   ...
# 379323  agent says thank you for calling best buy my n...
# 379324  agent says moment your phone number please.cus...
# 379325  agent says calling me back. this is name i hav...
# 379326  agent says hi thanks for calling best buy this...
# 379327  agent says calling best buy my name is name ma...
#
#                                  label
# 0                      troubleshooting
# 1                schedule installation
# 2                     trade in inquiry
# 3                     account security
# 4       product availability and stock
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from collections import Counter
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Amulya
# [nltk_data]     Cherian\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Amulya
# [nltk_data]     Cherian\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
def generate_summary(text,n):
    sentences = sent_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word.lower() for word in word_tokenize(text) if word.lower() not in stop_words and word.isalnum()]
    word_freq = Counter(words)
    sentence_scores = {}
    for sentence in sentences:
        sentence_words = [word.lower() for word in word_tokenize(sentence) if word.lower() not in stop_words and word.isalnum()]
        sentence_score = sum([word_freq[word] for word in sentence_words])
    if len(sentence_words) < 20:
        sentence_scores[sentence] = sentence_score\
        summary_sentences = sorted(sentence_scores, key=lambda x: sentence_scores[x], reverse=True)[:n]
        summary = ' '.join(summary_sentences)
        return summary
# Out:
#   Input In [19]
#     summary_sentences = sorted(sentence_scores, key=lambda x: sentence_scores[x], reverse=True)[:n]
#     ^
# SyntaxError: invalid syntax

# %%
pip install pandas bert-extractive-summarizer
# Out:
# ...
#
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# ...
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.4
#     Uninstalling colorama-0.4.4:
#       Successfully uninstalled colorama-0.4.4
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
# ...

# %%
import pandas as pd
from summarizer import Summarizer

def extractive_summarization(text):
    summarizer = Summarizer()
    summary = summarizer(text)
    return summary

def summarize_calls(file_path, output_csv_path):
    df = pd.read_excel(file_path)

    # Create a new column for summaries
    df['Summary'] = df['text'].apply(extractive_summarization)

    # Save the DataFrame with summaries to a new CSV file
    df.to_csv(output_csv_path, index=False)

# Example usage
file_path = 'training_dataset.xlsx'
output_csv_path = 'summarized_calls.csv'
summarize_calls(file_path, output_csv_path)
# Out:
# C:\Users\Amulya Cherian\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Amulya Cherian\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Amulya Cherian\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
import pandas as pd
from summarizer import Summarizer

def distilbert_summarization(text):
    summarizer = Summarizer('distilbert-base-uncased')
    summary = summarizer(text)
    return summary

def summarize_excel(input_excel, output_excel):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(input_excel)

    # Apply DistilBERT summarization to each row in the 'Transcript' column
    df['Summary'] = df['text'].apply(distilbert_summarization)

    # Save the DataFrame with summaries to a new Excel file
    df.to_excel(output_excel, index=False)

# Example usage
input_excel_path = 'training_dataset.xlsx'
output_excel_path = 'summarized_output.xlsx'
summarize_excel(input_excel_path, output_excel_path)
# Out:
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# C:\Users\Amulya Cherian\anaconda3\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Amulya Cherian\.cache\huggingface\hub\models--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
pip install pandas openpyxl transformers
# Out:
# ...
#
# ...

# %%
import pandas as pd
from transformers import pipeline

def xlnet_summarization(text):
    summarizer = pipeline('summarization', model='facebook/bart-large-cnn')
    summary = summarizer(text, max_length=150, min_length=50, length_penalty=2.0)
    return summary[0]['summary_text']

def summarize_excel(input_excel, output_excel):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(input_excel)

    # Apply XLNet summarization to each row in the 'Transcript' column
    df['Summary'] = df['text'].apply(xlnet_summarization)

    # Save the DataFrame with summaries to a new Excel file
    df.to_excel(output_excel, index=False)

# Example usage
input_excel_path = 'training_dataset.xlsx'
output_excel_path = 'summarized_output.xlsx'
summarize_excel(input_excel_path, output_excel_path)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# C:\Users\Amulya Cherian\anaconda3\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Amulya Cherian\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
pip install summa pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54411 sha256=39bcfa8dad9f20844a309d93cbb62c7cc3774ddbda97d2a8e3b183f9031f3db6
#   Stored in directory: c:\users\amulya cherian\appdata\local\pip\cache\wheels\ed\2c\5f\a0ccc5955d44d2cea78729f4425e73f818d2629517f7af0f8b
# Successfully built summa
# ...

# %%
import pandas as pd
from summa import summarizer

def textrank_summarization(text):
    summary = summarizer.summarize(text)
    return summary

def summarize_excel(input_excel, output_excel):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(input_excel)

    # Apply TextRank summarization to each row in the 'Transcript' column
    df['Summary'] = df['text'].apply(textrank_summarization)

    # Save the DataFrame with summaries to a new Excel file
    df.to_excel(output_excel, index=False)

# Example usage
input_excel_path = 'training_dataset.xlsx'
output_excel_path = 'summarized_output_textrank.xlsx'
summarize_excel(input_excel_path, output_excel_path)

# %%
import pandas as pd
from summa import keywords
from summa import summarizer

def textrank_extractive_summarization(text, num_sentences=3):
    # Extract keywords using TextRank
    extracted_keywords = keywords.keywords(text)

    # Use TextRank for extractive summarization
    summary = summarizer.summarize(text, words=num_sentences*50)  # Adjust words parameter based on your desired summary length

    return summary, extracted_keywords

def label_excel_with_textrank(input_excel_path, output_excel_path, num_sentences=3):
    # Read the Excel file
    df = pd.read_excel(input_excel_path)

    # Create new columns for summary and keywords
    df['Summary'] = ''
    df['Keywords'] = ''

    # Apply TextRank extractive summarization and labeling to each row
    for index, row in df.iterrows():
        text = str(row['text'])  # Assuming your Excel column is named 'Text'
        summary, keywords = textrank_extractive_summarization(text, num_sentences)
        df.at[index, 'Summary'] = summary
        df.at[index, 'Keywords'] = keywords

    # Save the labeled Excel file
    df.to_excel(output_excel_path, index=False)

# Example usage
input_excel_path = 'training_dataset.xlsx'  # Replace with your input Excel file path
output_excel_path = 'output_data_labeled.xlsx'  # Replace with your desired output Excel file path

label_excel_with_textrank(input_excel_path, output_excel_path)
